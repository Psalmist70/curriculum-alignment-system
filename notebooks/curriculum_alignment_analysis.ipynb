# %% [markdown]
# <a href="https://colab.research.google.com/github/Psalmist70/curriculum-alignment-system/blob/main/notebooks/curriculum_alignment_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Psalmist70/curriculum-alignment-system.github
# Out:
# Cloning into 'curriculum-alignment-system.github'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

path = "/content/drive/MyDrive/curriculum-alignment-system/curriculum_cleaned.csv"

df = pd.read_csv(path, encoding="latin1")

df.head()
# Out:
#   course_id                                       course_title  \
# 0    CPE401             Computer Architecture and Organization
# 1    CSC403                            Principles of Compilers
# 2    CPE405  Introduction to Microprocessor Technology & Mi...
# 3    CSC407                 Techniques in Software Development
# 4    CPE409                   Microprocessor Design Laboratory
#
#                                   course_description  \
# 0  This course examines the structural and functi...
# 1  This course introduces the fundamental concept...
# 2  This course focuses on microprocessor systems ...
# 3  This course provides an overview of software d...
# 4  This course involves practical implementation ...
#
#                                     program_outcomes  level  semester
# 0  Analyze CPU components; design digital systems...    400         1
# 1  Explain compiler stages; implement lexical sca...    400         1
# 2  Design I/O interfaces; manage interrupt struct...    400         1
# 3  Apply software design principles; practice sof...    400         1
# 4  Apply architectural theory; execute microcontr...    400         1

# %%
df.shape
df.columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   course_id           23 non-null     object
#  1   course_title        23 non-null     object
#  2   course_description  23 non-null     object
#  3   program_outcomes    23 non-null     object
#  4   level               23 non-null     int64
#  5   semester            23 non-null     int64
# dtypes: int64(2), object(4)
# memory usage: 1.2+ KB

# %%
df["desc_length"] = df["course_description"].astype(str).apply(len)
df["desc_length"].describe()
# Out:
# count     23.000000
# mean     405.000000
# std      127.544288
# min      245.000000
# 25%      322.000000
# 50%      373.000000
# 75%      439.500000
# max      709.000000
# Name: desc_length, dtype: float64

# %%
df["course_title"] = df["course_title"].astype(str)
df["course_description"] = df["course_description"].astype(str)

# %%
if "program_outcomes" in df.columns:
      df["program_outcomes"] = df["program_outcomes"].astype(str)

# %%
df["course_description"] = df["course_description"].str.lower()
df["program_outcomes"] = df["program_outcomes"].str.lower()

# %%
df["course_description"] = df["course_description"].str.replace("\n", " ")
df["program_outcomes"] = df["program_outcomes"].str.replace("\n", " ")

# %%
import pandas as pd

path = "/content/drive/MyDrive/curriculum-alignment-system/kaggle_jobs.csv"

df = pd.read_csv(path)

df.head()
# Out:
#       location Job Posting Date           Job Title                     Role  \
# 0     Ashgabat       2022-12-19       Web Developer   Frontend Web Developer
# 1        Macao       2022-09-14  Operations Manager  Quality Control Manager
# 2  George Town       2023-04-10             Teacher        Classroom Teacher
# 3   Ṣo Tom̩       2022-09-20      UX/UI Designer  User Interface Designer
# 4         Male       2022-02-19      UX/UI Designer     Interaction Designer
#
#                                      Job Description  \
# 0  Frontend Web Developers design and implement u...
# 1  Quality Control Managers establish and enforce...
# 2  A Classroom Teacher educates students in a spe...
# 3  User Interface Designers focus on the visual a...
# 4  Interaction Designers specialize in designing ...
#
#                            skills                           Company  \
# 0   ['css', 'html', 'javascript']      PNC Financial Services Group
# 1                  ['compliance']  United Services Automobile Assn.
# 2      ['assessment', 'teaching']                             FedEx
# 3                  ['typography']                      Ryder System
# 4  ['prototyping', 'wireframing']     Zee Entertainment Enterprises
#
#    experience_min  experience_max qualification_level  salary_min  salary_max
# 0               2              12           bachelors       56000      116000
# 1               0              12                 phd       61000      104000
# 2               3              15                 phd       63000      103000
# 3               2               8               other       65000      102000
# 4               2               9               other       65000      102000

# %%
df.info()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1145965 entries, 0 to 1145964
# Data columns (total 12 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   location             1145965 non-null  object
#  1   Job Posting Date     1145965 non-null  object
#  2   Job Title            1145965 non-null  object
#  3   Role                 1145965 non-null  object
#  4   Job Description      1145965 non-null  object
#  5   skills               1145965 non-null  object
#  6   Company              1145965 non-null  object
#  7   experience_min       1145965 non-null  int64
#  8   experience_max       1145965 non-null  int64
#  9   qualification_level  1145965 non-null  object
#  10  salary_min           1145965 non-null  int64
#  11  salary_max           1145965 non-null  int64
# dtypes: int64(4), object(8)
# memory usage: 104.9+ MB
# Index(['location', 'Job Posting Date', 'Job Title', 'Role', 'Job Description',
#        'skills', 'Company', 'experience_min', 'experience_max',
#        'qualification_level', 'salary_min', 'salary_max'],
#       dtype='object')

# %%
df = df[[
      "Job Title",
      "Job Description",
      "skills"
]]

# %%
df.columns = ["job_title", "job_description", "skills"]

# %%
df.dropna(inplace=True)

# %%
df["job_title"] = df["job_title"].str.lower().str.strip()
df["job_description"] = df["job_description"].str.lower().str.strip()
df["skills"] = df["skills"].str.lower().str.strip()

# %%
df.drop_duplicates(inplace=True)

# %%
len(df)
# Out:
# 1145965

# %%
df = df.sample(n=50000, random_state=42)

# %%
df.reset_index(drop=True, inplace=True)

# %%
save_path = "/content/drive/MyDrive/curriculum-alignment-system/job_datasetfull_cleaned.csv"
df.to_csv(save_path, index=False)
